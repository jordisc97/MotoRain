# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import json
from difflib import get_close_matches

class MeteoCatScraper:
    def __init__(self, municipalities_json_path='municipalities.json'):
        self.base_url = "https://www.meteo.cat/prediccio/municipal/"
        with open(municipalities_json_path, 'r', encoding='utf-8') as f:
            municipalities = json.load(f)
        
        self.municipalities_df = pd.DataFrame(municipalities)
        self.municipalities_df["nom_lower"] = self.municipalities_df["nom"].str.lower()

    def get_municipality_record(self, name: str) -> dict:
        """
        Finds a municipality record from the local JSON file.
        """
        name_lower = name.lower()
        matches = get_close_matches(name_lower, self.municipalities_df["nom_lower"], n=1, cutoff=0.6)
        if not matches:
            raise ValueError(f"No municipality found close to '{name}'")

        matched_name = matches[0]
        row = self.municipalities_df.loc[self.municipalities_df["nom_lower"] == matched_name].iloc[0]

        return {
            "codi": row["codi"],
            "nom": row["nom"],
            "coordenades": {
                "latitud": row["coordenades"]["latitud"],
                "longitud": row["coordenades"]["longitud"],
            },
            "comarca": {
                "codi": row["comarca"]["codi"],
                "nom": row["comarca"]["nom"],
            },
            "slug": row.get("slug"),
        }
    
    def scrape_weather_data_by_code(self, municipality_code: str) -> pd.DataFrame:
        """
        Scrapes weather data for a given municipality code.
        """
        url = self.base_url + municipality_code
        today = datetime.now()

        day_map = {
            'Avui': today,
            'Demà': today + timedelta(days=1),
            'Demà passat': today + timedelta(days=2)
        }

        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        city_elem = soup.find('div', id='bit-1')
        city_h2 = city_elem.find('h2') if city_elem else None
        city_name = city_h2.get_text(strip=True) if city_h2 else ''

        weather_data = []

        for day_label, day_date in day_map.items():
            day_element = soup.find('strong', string=day_label)
            if not day_element:
                continue

            tables = []
            sibling = day_element.find_next_sibling()
            while sibling and sibling.name == "table":
                tables.append(sibling)
                sibling = sibling.find_next_sibling()
            if not tables:
                tables = day_element.find_all_next('table', limit=3)
            
            if not tables:
                continue

            header_cells = tables[0].find_all(['th', 'td'])
            times_raw = [cell.get_text(strip=True) for cell in header_cells[1:]]

            times = []
            for t in times_raw:
                if 'h' in t:
                    hr = t.replace('h', '').strip()
                    if hr.isdigit():
                        hour = int(hr)
                        if 0 <= hour <= 23:
                            times.append(f"{hour:02d}:00")

            day_dict = {
                'City': [], 'Day': [], 'Time': [], 'Temperatura (°C)': [],
                'Precipitació acumulada (mm)': [], 'Vent (km/h)': []
            }

            temperature_row, precipitation_row, wind_row = None, None, None

            for table in tables:
                for tr in table.find_all('tr'):
                    cells = [td.get_text(strip=True) for td in tr.find_all(['td', 'th'])]
                    if not cells:
                        continue
                    label, values = cells[0], cells[1:]
                    if label == 'Temperatura (°C)':
                        temperature_row = values
                    elif label == 'Precipitació acumulada (mm)':
                        precipitation_row = values
                    elif label.startswith('Vent'):
                        wind_row = values
                if all((temperature_row, precipitation_row, wind_row)):
                    break

            day_str = day_date.strftime("%d/%m/%y")

            for i in range(len(times)):
                day_dict['City'].append(city_name)
                day_dict['Day'].append(day_str)
                day_dict['Time'].append(times[i])
                day_dict['Temperatura (°C)'].append(temperature_row[i] if temperature_row and i < len(temperature_row) else '')
                day_dict['Precipitació acumulada (mm)'].append(precipitation_row[i] if precipitation_row and i < len(precipitation_row) else '')
                day_dict['Vent (km/h)'].append(wind_row[i] if wind_row and i < len(wind_row) else '')

            weather_data.append(pd.DataFrame(day_dict))

        if not weather_data:
            return pd.DataFrame()
            
        return pd.concat(weather_data, ignore_index=True)
    
    def get_weather_by_name(self, name: str) -> pd.DataFrame:
        """
        A convenience method to get weather data by municipality name.
        """
        record = self.get_municipality_record(name)
        return self.scrape_weather_data_by_code(record['codi'])

# %%
# Example usage:
scraper = MeteoCatScraper()
minicipality_name = "st quirze del v"
df_weather = scraper.get_weather_by_name(minicipality_name)
df_weather
# Out:
#                       City       Day   Time Temperatura (°C)  \
# 0   Sant Quirze del Vallès  09/11/25  18:00               13
# 1   Sant Quirze del Vallès  09/11/25  19:00               12
# 2   Sant Quirze del Vallès  09/11/25  20:00               11
# 3   Sant Quirze del Vallès  09/11/25  21:00               11
# 4   Sant Quirze del Vallès  09/11/25  22:00               10
# 5   Sant Quirze del Vallès  09/11/25  23:00               10
# 6   Sant Quirze del Vallès  10/11/25  00:00                9
# 7   Sant Quirze del Vallès  10/11/25  01:00                9
# 8   Sant Quirze del Vallès  10/11/25  02:00                9
# 9   Sant Quirze del Vallès  10/11/25  03:00                8
# 10  Sant Quirze del Vallès  10/11/25  04:00                8
# 11  Sant Quirze del Vallès  10/11/25  05:00                8
# 12  Sant Quirze del Vallès  10/11/25  06:00                8
# 13  Sant Quirze del Vallès  10/11/25  07:00                8
# 14  Sant Quirze del Vallès  10/11/25  08:00                9
# 15  Sant Quirze del Vallès  10/11/25  09:00               11
# 16  Sant Quirze del Vallès  10/11/25  10:00               13
# 17  Sant Quirze del Vallès  10/11/25  11:00               15
# 18  Sant Quirze del Vallès  10/11/25  12:00               16
# 19  Sant Quirze del Vallès  10/11/25  13:00               17
# 20  Sant Quirze del Vallès  10/11/25  14:00               18
# 21  Sant Quirze del Vallès  10/11/25  15:00               18
# 22  Sant Quirze del Vallès  10/11/25  16:00               17
# 23  Sant Quirze del Vallès  10/11/25  17:00               16
# 24  Sant Quirze del Vallès  10/11/25  18:00               13
# 25  Sant Quirze del Vallès  10/11/25  19:00               12
# 26  Sant Quirze del Vallès  10/11/25  20:00               12
# 27  Sant Quirze del Vallès  10/11/25  21:00               12
# 28  Sant Quirze del Vallès  10/11/25  22:00               11
# 29  Sant Quirze del Vallès  10/11/25  23:00               10
# 30  Sant Quirze del Vallès  11/11/25  00:00               10
# 31  Sant Quirze del Vallès  11/11/25  01:00                9
# 32  Sant Quirze del Vallès  11/11/25  02:00                9
# 33  Sant Quirze del Vallès  11/11/25  03:00                9
# 34  Sant Quirze del Vallès  11/11/25  04:00                9
# 35  Sant Quirze del Vallès  11/11/25  05:00                8
# 36  Sant Quirze del Vallès  11/11/25  06:00                8
# 37  Sant Quirze del Vallès  11/11/25  07:00                8
# 38  Sant Quirze del Vallès  11/11/25  08:00                9
# 39  Sant Quirze del Vallès  11/11/25  09:00               12
# 40  Sant Quirze del Vallès  11/11/25  10:00               14
# 41  Sant Quirze del Vallès  11/11/25  11:00               16
# 42  Sant Quirze del Vallès  11/11/25  12:00               17
# 43  Sant Quirze del Vallès  11/11/25  13:00               18
# 44  Sant Quirze del Vallès  11/11/25  14:00               19
# 45  Sant Quirze del Vallès  11/11/25  15:00               19
# 46  Sant Quirze del Vallès  11/11/25  16:00               18
# 47  Sant Quirze del Vallès  11/11/25  17:00               16
# 48  Sant Quirze del Vallès  11/11/25  18:00               14
# 49  Sant Quirze del Vallès  11/11/25  19:00               13
# 50  Sant Quirze del Vallès  11/11/25  20:00               12
# 51  Sant Quirze del Vallès  11/11/25  21:00               12
# 52  Sant Quirze del Vallès  11/11/25  22:00               11
# 53  Sant Quirze del Vallès  11/11/25  23:00               11
#
#    Precipitació acumulada (mm) Vent (km/h)
# 0                            0           2
# 1                            0           3
# 2                            0           3
# 3                            0           2
# 4                            0           2
# 5                            0           2
# 6                            0           2
# 7                            0           2
# 8                            0           2
# 9                            0           3
# 10                           0           3
# 11                           0           3
# 12                           0           3
# 13                           0           3
# 14                           0           2
# 15                           0           4
# 16                           0           7
# 17                           0          11
# 18                           0          12
# 19                           0          10
# 20                           0           8
# 21                           0           9
# 22                           0           8
# 23                           0           3
# 24                           0           3
# 25                           0           4
# 26                           0           3
# 27                           0           3
# 28                           0           2
# 29                           0           3
# 30                           0           3
# 31                           0           3
# 32                           0           2
# 33                           0           2
# 34                           0           3
# 35                           0           3
# 36                           0           3
# 37                           0           3
# 38                           0           2
# 39                           0           1
# 40                           0           2
# 41                           0           3
# 42                           0           6
# 43                           0           8
# 44                           0           7
# 45                           0           7
# 46                           0           6
# 47                           0           4
# 48                           0           3
# 49                           0           2
# 50                           0           2
# 51                           0           3
# 52                           0           3
# 53                           0           3
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
